# %% [markdown]
# # BM25 Baseline
#
# This notebook inspects the latest saved BM25 baseline artifacts from the shared pipeline outputs.
#
# Run `venv/bin/python src/run_pipeline.py --profile medium` first if you want fresh results.

# %%
import json
from pathlib import Path

ROOT = Path.cwd().resolve().parent if Path.cwd().name == "notebooks" else Path.cwd().resolve()

with open(ROOT / "data/experiments/bm25_metrics.json", encoding="utf-8") as handle:
    bm25_metrics = json.load(handle)

with open(ROOT / "data/experiments/summary.json", encoding="utf-8") as handle:
    summary = json.load(handle)

bm25_metrics, summary.get("train_queries"), summary.get("test_queries")
# Out:
# ({'ndcg@10': 0.4414082504470804, 'map': 0.41233333333333333}, 450, 50)
